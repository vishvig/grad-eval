# %% [markdown]
# # Coding Task 4
#
# ## Scenario
#
# In recent years, teleportation technology has become viable for interstellar travel. A **teleportation machine** can transport a traveler between any two planets as long as the distance between them is within a fixed threshold. This is beacuse the teleporation machine works on the principle of disintegration and reintegration of molecules between the target and destination. The threshold is the teleportation device's limitation and any path taken beyond that will lead to fatal disintegration of the traveller. Each planet is assigned a position in 3D space, and travel is only allowed between **direct neighbors** — planets within a maximum teleportation distance.
#
# Your mission: help scientists **determine the shortest path from Earth to a specific planet** using the newly available planetary coordinates and teleportation constraints.
#
# The Earth is located at coordinate `(0, 0, 0)`. You are provided with a dataset of **planet names** and their **3D coordinates** (`x`, `y`, `z`). You are also provided with the name of the **target planet**, and the teleportation machine's **maximum range** (distance constraint).
#
# ---
#
# ## Available Data
#
# The dataset should be available to you as part of the zip file you downloaded from the coding task assessment. This includes:
#
# - `Planet`: Name of the planet
# - `x`, `y`, `z`: Spatial coordinates of the planet
# - `Rock`, `Water`, `Air`, `Fire`: Elemental composition proportions of the planet (each between 0 and 1)
# - `Liveable`: Binary label (`Yes`/`No`) indicating if the planet is habitable
#
# The Earth is not listed in the dataset, but is assumed to be the origin.
#
# ---
#
# ## Your Task
#
# In your Jupyter Notebook:
#
# 1. Write a function that finds the **shortest path from Earth to a given target planet** using the provided teleportation range constraint.
# 2. The function should:
#    - Begin from Earth at `(0, 0, 0)`
#    - Traverse through neighboring planets (within distance constraint)
#    - Return the sequence of planet names in the teleportation path and the total number of steps and distance
# 3. You are not exepcted to upload any output file to the portal for this task. But ensure you have the path output printed in your final cell of the notebook.
#
#
# *Indicative example:*
# ```
# Source planet - Earth - (0,0,0)
#
# Target planet - Planet_567 - (756, 657, -576)
#
# Path - [Earth, Planet_123, Planet_234, Planet_345, Planet_456, Planet_567]
# ```
#
# You are **not required** to use built-in shortest path functions — the focus is on your logic.
#
# ---
#
# ## What You Can Use
#
# - Python (NumPy, Pandas, etc.)
# - Data structures like graphs, trees, or priority queues (you may use `networkx` if desired)
# - `scipy.spatial` or any method to compute 3D Euclidean distances
# - You are free to write your own logic for graph traversal (recommended!)
#
# > *Please do not use libraries like `dijkstra_path` or any shortest path one-liners. The goal is to evaluate your algorithm-building skills.*
#
# ---
#
# ## Evaluation Criteria
#
# - Correctness of your shortest path implementation
# - Ability to dynamically compute neighbors based on 3D distance
# - Logical structure, code clarity, and modularity
# - Handling of edge cases (e.g., unreachable planets, cycles)
# - Efficient use of data structures and distance calculations
#
# ---
#
# ### Bonus
#
# Implement the **shortest path with constraints**:
#
# - Every journey starts from Earth with **100 health points (HP)**
# - Each visited planet reduces or restores health:
#   - Fire planet: -20HP
#   - Air planet: -15HP
#   - Water planet: -10HP
#   - Rock planet: -5HP
#   - Liveable planet: Resets health to 100HP
# - A planet’s dominant element is the one with the **highest proportion**
# - If no path can be taken without reaching 0 health, return that the path is **not possible**
#
# 💡 Return the full path, total distance, and remaining health (or failure message).
#
# ---
#
# Good luck!

# %%
# YOUR RESPONSE STARTS FROM HERE
