# %% [markdown]
# # Coding task 2
#
# ## Scenario
#
# In the not-so-distant future, Earth's astronomers have developed advanced instruments that can detect **3 different signals** from deep space. These signals are captured from distant **solar systems**, **stars**, and **galaxies**, but their true nature remains unknown.
#
# To decode this cosmic mystery, astronomers need your data science expertise to **analyze the signals** and **identify meaningful clusters** that may represent different celestial phenomena.
#
# Each signal spectrum contains values simulated from a multimodal distribution representing natural astrophysical variations in emission levels.
#
# Your goal is to apply **unsupervised learning techniques** to uncover the hidden structure in the universe.
#
# ---
#
# ## Available Data
#
# The dataset should be available to you as part of the zip file you downloaded from the coding task assessment. It should contain 3 signal columns `signal_1`, `signal_2`, `signal_3` (all real and continuous) and `10000` datapoints. Use the same random `seed` setting provided on your the first task.
#
# ---
#
# ## Your Task
#
# You are to complete the following:
#
# 1. **Load, inspect and analyze** the provided signal data.
# 2. **Standardize** the features appropriately.
# 3. Use the any suitable technique) to determine the optimal number of clusters.
# 4. Apply a clustering algorithm to group the data.
# 5. **Evaluate** your clustering using relevant metrics.
# 6. **Visualize** the results.
# 7. Provide a brief **explanation** of your choices.
# 8. Upload the clustering output csv on the portal.
#
# CSV output format:
# | output    |
# | -------- |
# | 1  |
# | 4 |
# | 5    |
# | 3    |
# | 2    |
#
# and so on for all data points given in the input. 1, 2, 3, 4, 5 are example cluster labels. Note that the problem may or may not have 5 clusters and the labels given here are indicative of how the output is expected.
#
# ---
#
# ## What You Can Use
#
# - Python (NumPy, Pandas etc.)
# - Standard data science libraries for preprocessing, clustering, evaluation, and plotting (scikit-learn, matplotlib, seaborn, etc.).
#
# > *Do not use AutoML tools for this task.*
#
# ---
#
# ## Evaluation Criteria
#
# - Code is well-structured, readable, and logically organized
# - Appropriate preprocessing, cluster selection, and algorithm choice
# - Proper use of releavant metrics
# - Effective use of cluster plots; clear labeling and legends
# - Clarity of explanantion
# ---
#
# ### Bonus
#
# - An implementation of a clustering algorithm from scratch. *WOULD LOVE TO SEE THIS AND THIS IS A BIG BONUS!*
# - Try multiple clustering algorithms and compare their performance.
# - An attempt to interpret the results.
#   - Should there have been more clusters on your output based on your analysis?
#   - If so, what casued your current implementation to not extract these insights?
#   - Was it a gap with the data or the algorithm?
#
# Good luck!

# %%
# YOUR RESPONSE STARTS FROM HERE
